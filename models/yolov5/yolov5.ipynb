# %% [markdown]
# # YOLOv5

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
import shutil

# %% [markdown]
# ### Checking GPU device ids

# %%
# !nvidia-smi
# Out:
# Fri Jul 28 16:51:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# %pwd
# Out:
# '/kaggle/working'

# %%
len(os.listdir('/kaggle/input/traffic/datasets/images/train'))
# Out:
# 16331

# %% [markdown]
# ### Cloning ultralytics YOLOv5 repo

# %%
# Cloning the yolov5 repository
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15829, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 15829 (delta 20), reused 29 (delta 4), pack-reused 15768
# Receiving objects: 100% (15829/15829), 14.66 MiB | 21.38 MiB/s, done.
# Resolving deltas: 100% (10829/10829), done.

# %%
# Replacing the configurations
shutil.copy('/kaggle/input/yolov5-config/dataset.yaml','/kaggle/working/yolov5/dataset.yaml')
shutil.copy('/kaggle/input/yolov5-config/yolov5s.yaml','/kaggle/working/yolov5/models/yolov5s.yaml')
# Out:
# '/kaggle/working/yolov5/models/yolov5s.yaml'

# %%
# %cd /kaggle/working/yolov5
# Out:
# /kaggle/working/yolov5

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.0/605.0 kB 11.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install wandb

# %%
# Using wandb for logging and training visuals
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# Installing requirements
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.0/804.0 kB 13.0 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.8.0
#     Uninstalling setuptools-59.8.0:
#       Successfully uninstalled setuptools-59.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-api 1.18.0 requires importlib-metadata~=6.0.0, but you have importlib-metadata 6.7.0 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.1 which is incompatible.
# ...

# %% [markdown]
# ### Training the model with parameters
# #### Multiple iterations were trained with hyper-parameters tuned in the config files

# %%
# Training the model with hyper-parameters
# !python train.py --img 640 --epochs 10 --data dataset.yaml --weights yolov5s.pt --name GTSRB_yolov5 --cfg models/yolov5s.yaml --save-period 2 --optimizer 'Adam' --device 0,1 --batch-size 32
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# ...

# %% [markdown]
# ### Testing

# %%
# !python detect.py --img 640 --source /kaggle/input/traffic/datasets/images/test --weights /kaggle/working/yolov5/runs/train/GTSRB_yolov52/weights/best.pt --device 0,1 --save-txt --save-conf --save-crop
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# %pwd
# Out:
# '/kaggle/working/yolov5'

# %% [markdown]
# ### Zipping the runs folder

# %%
# !zip -r run_yolov5.zip /kaggle/working/yolov5/runs
# Out:
#   adding: kaggle/working/yolov5/runs/ (stored 0%)
#   adding: kaggle/working/yolov5/runs/detect/ (stored 0%)
#   adding: kaggle/working/yolov5/runs/detect/exp/ (stored 0%)
#   adding: kaggle/working/yolov5/runs/detect/exp/04772.png (stored 0%)
#   adding: kaggle/working/yolov5/runs/detect/exp/07773.png (deflated 5%)
#   adding: kaggle/working/yolov5/runs/detect/exp/05160.png (stored 0%)
#   adding: kaggle/working/yolov5/runs/detect/exp/04540.png (stored 0%)
#   adding: kaggle/working/yolov5/runs/detect/exp/01901.png (deflated 10%)
#   adding: kaggle/working/yolov5/runs/detect/exp/07198.png (deflated 5%)
#   adding: kaggle/working/yolov5/runs/detect/exp/04436.png (deflated 1%)
#   adding: kaggle/working/yolov5/runs/detect/exp/07311.png (deflated 1%)
#   adding: kaggle/working/yolov5/runs/detect/exp/04201.png (deflated 12%)
#   adding: kaggle/working/yolov5/runs/detect/exp/02637.png (stored 0%)
#   adding: kaggle/working/yolov5/runs/detect/exp/08193.png (deflated 0%)
# ...
